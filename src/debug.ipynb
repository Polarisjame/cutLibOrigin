# %%
import torch
import json

# data = torch.load("/data/zhoulingfeng/data_cutLib/save_subgraph/save_designs_b16/iwls2022/blockset_ex27_hop3_batch16.pt")
with open("/home/zhoulingfeng/EDAProject/cutLibTest/data/save_json_iwls2022/ex65/data_2.json", "r") as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['x_data', 'edge_index', 'pos', 'cell_struct'])

# %%
data['cell_struct']['6445']
# Out:
# {'cuts': [[17476, [1612, 6444], 2],
#   [1028, [1612, 5752, 6443], 3],
#   [57568, [18, 1611, 6444], 3],
#   [4144, [4, 1612, 5752, 6442], 4],
#   [16, [1612, 2222, 5751, 6443], 4],
#   [224, [18, 1611, 5752, 6443], 4],
#   [47616, [18, 762, 1610, 6444], 4],
#   [61696, [16, 17, 1611, 6444], 4],
#   [62976, [7, 14, 1611, 6444], 4],
#   [16, [1612, 2222, 3621, 5750, 6443], 5]],
#  'supergateIndex': 9,
#  'Area': 1.63,
#  'nodes': [[6445, 16407, 1612, 6444],
#   [6445, 16407, 1612, 6444, 19593, 6443, 5752],
#   [6445, 16407, 1612, 15247, 18, 16406, 1611, 6444],
#   [6445, 16407, 1612, 6444, 19593, 6443, 4, 6442, 5752],
#   [6445, 16407, 1612, 6444, 19593, 6443, 5752, 16857, 2222, 5751],
#   [6445, 16407, 1612, 15247, 18, 16406, 1611, 6444, 19593, 6443, 5752],
#   [6445, 16407, 1612, 15247, 18, 16406, 1611, 15796, 762, 1610, 6444],
#   [6445, 16407, 1612, 15247, 18, 15245, 16, 15246, 17, 16406, 1611, 6444],
#   [6445,
#    16407,
#    1612,
#    15247,
#    18,
#    15245,
#    16,
# ...

# %%
data['train'][0]['blocks'][-1].dstdata['feats']['cell']
# Out:
# tensor([[ 1.0000e+00,  1.3000e+01,  8.0000e+00,  5.0000e+00,  3.1100e+02,
#           1.7660e+02,  1.1462e+02,  8.0000e-01,  4.0000e+00,  4.0000e+00,
#           0.0000e+00,  9.0000e+00,  1.8000e+00,  1.0000e+00,  2.5000e-01,
#           1.0000e+00,  7.4074e-02,  0.0000e+00,  2.6979e-01,  3.2960e-16,
#           1.5836e-01,  4.5484e-01,  6.7510e-01,  1.0000e+00,  2.3188e+08],
#         [ 1.0000e+00,  2.5000e+01,  2.0000e+00,  0.0000e+00,  2.7500e+02,
#           2.1033e+02,  4.9128e+01,  1.0000e+00,  4.5000e+00,  3.0000e+00,
#           1.5000e+00,  7.0000e+00,  1.7500e+00,  2.0000e+00,  7.5000e-01,
#           2.0000e+00,  1.2245e-01,  4.0816e-02,  2.8750e-01,  1.3704e-16,
#           2.4407e-01,  8.3097e-01,  1.0000e+00,  1.1690e+00,  1.9631e+09],
#         [ 1.0000e+00,  9.0000e+00,  1.7000e+01,  3.0000e+00,  5.0000e+00,
#           4.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  1.0000e+00,
#           0.0000e+00,  3.0000e+00,  1.5000e+00,  1.0000e+00,  0.0000e+00,
# ...
